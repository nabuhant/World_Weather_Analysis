# %%
#Import Dependencies
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs # will give a zip object in a memory location

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %%
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
display(len(cities))
display(cities)
# Out:
# 735
# ['castro',
#  'severo-kurilsk',
#  'verkhoyansk',
#  'rikitea',
#  'provideniya',
#  'carnarvon',
#  'chokurdakh',
#  'mataura',
#  'korla',
#  'souillac',
#  'vila velha',
#  'coquimbo',
#  'westport',
#  'camana',
#  'longyearbyen',
#  'hermanus',
#  'samusu',
#  'tasiilaq',
#  'lubyany',
#  'wenatchee',
#  'yarada',
#  'butaritari',
#  'cayenne',
#  'albany',
#  'todos santos',
#  'tiarei',
#  'lisakovsk',
#  'busselton',
#  'ushuaia',
#  'rundu',
#  'saldanha',
#  'ouargaye',
#  'port augusta',
#  'grindavik',
#  'bluff',
#  'puerto ayora',
#  'vaitupu',
#  'hithadhoo',
#  'livani',
#  'deogarh',
#  'brae',
#  'vaini',
#  'bambous virieux',
#  'tuktoyaktuk',
#  'praia da vitoria',
#  'punta arenas',
#  'camopi',
#  'east london',
#  'taolanaro',
#  'tezu',
#  'qaanaaq',
#  'bredasdorp',
#  'ixtapa',
#  'ayer itam',
#  'avarua',
#  'new norfolk',
#  'rawson',
#  'hobart',
#  'herat',
#  'rocha',
#  'jamestown',
#  'mporokoso',
#  'buraydah',
#  'san quintin',
#  'semey',
#  'paamiut',
#  'dikson',
#  'saskylakh',
#  'upernavik',
#  'merauke',
#  'port alfred',
#  'sorland',
#  'krasnoselkup',
#  'klaksvik',
#  'tautira',
#  'ilulissat',
#  'touros',
#  'hit',
#  'igarka',
#  'yellowknife',
#  'mauriti',
#  'faanui',
#  'mar del plata',
#  'akyab',
#  'arraial do cabo',
#  'xining',
#  'caravelas',
#  'hilo',
#  'nyurba',
#  'tsihombe',
#  'bargal',
#  'te anau',
#  'barbar',
#  'pevek',
#  'norilsk',
#  'batsfjord',
#  'georgetown',
#  'karratha',
#  'cape town',
#  'atar',
#  'bacabal',
#  'vorkuta',
#  'lata',
#  'novoagansk',
#  'tandil',
#  'deputatskiy',
#  'the pas',
#  'cidreira',
#  'yalta',
#  'kosa',
#  'louisbourg',
#  'itarema',
#  'erzin',
#  'talnakh',
#  'kapaa',
#  'guerrero negro',
#  'nikolskoye',
#  'narsaq',
#  'rumonge',
#  'mahebourg',
#  'chuy',
#  'mirnyy',
#  'ahipara',
#  'tupelo',
#  'kununurra',
#  'belyy yar',
#  'freeport',
#  'mangrol',
#  'cabedelo',
#  'kodiak',
#  'amapa',
#  'cabo san lucas',
#  'naryan-mar',
#  'airai',
#  'victoria',
#  'hofn',
#  'nalut',
#  'bengkulu',
#  'svetlyy',
#  'ancud',
#  'udachnyy',
#  'khorixas',
#  'tiksi',
#  'port elizabeth',
#  'zyryanovskiy',
#  'harper',
#  'campbell river',
#  'thompson',
#  'luderitz',
#  'basco',
#  'ploemeur',
#  'bismarck',
#  'pangnirtung',
#  'havre-saint-pierre',
#  'illoqqortoormiut',
#  'mao',
#  'bulgan',
#  'agirish',
#  'hobyo',
#  'keti bandar',
#  'nantucket',
#  'pochinki',
#  'hojai',
#  'price',
#  'hoima',
#  'saint-philippe',
#  'atuona',
#  'mastic beach',
#  'mys shmidta',
#  'grand gaube',
#  'zyryanovsk',
#  'matara',
#  'bonoua',
#  'martapura',
#  'berezovyy',
#  'cockburn town',
#  'kiama',
#  'sao filipe',
#  'vilkaviskis',
#  'pozo colorado',
#  'salalah',
#  'iqaluit',
#  'evensk',
#  'lebu',
#  'vestmannaeyjar',
#  'rayong',
#  'tambovka',
#  'san cristobal',
#  'mount gambier',
#  'geraldton',
#  'laguna',
#  'rio gallegos',
#  'mocuba',
#  'fortuna',
#  'new ulm',
#  'kemijarvi',
#  'bud',
#  'luganville',
#  'torbay',
#  'carutapera',
#  'kutum',
#  'abu dhabi',
#  'broome',
#  'belushya guba',
#  'hovd',
#  'kenora',
#  'gizo',
#  'awbari',
#  'ponta do sol',
#  'port lincoln',
#  'yulara',
#  'moron',
#  'kirakira',
#  'kisangani',
#  'yeppoon',
#  'khandyga',
#  'jambi',
#  'skjervoy',
#  'arlit',
#  'hoquiam',
#  'wanxian',
#  'perpignan',
#  'college',
#  'luanda',
#  'lujan',
#  'jiddah',
#  'poltsamaa',
#  'nizhneyansk',
#  'chimore',
#  'ayan',
#  'itaituba',
#  'lagoa',
#  'sentyabrskiy',
#  'kroya',
#  'san patricio',
#  'beckley',
#  'tabiauea',
#  'egvekinot',
#  'banyo',
#  'aswan',
#  'nouadhibou',
#  'zhuhai',
#  'lorengau',
#  'preobrazheniye',
#  'rio verde de mato grosso',
#  'catabola',
#  'trebur',
#  'sitka',
#  'duobao',
#  'barentsburg',
#  'amderma',
#  'quchan',
#  'palabuhanratu',
#  'taltal',
#  'khatanga',
#  'radhanpur',
#  'tevriz',
#  'vitimskiy',
#  'tual',
#  'lagos',
#  'portland',
#  'thunder bay',
#  'carlet',
#  'naze',
#  'gongzhuling',
#  'calabozo',
#  'alyangula',
#  'kavieng',
#  'bethel',
#  'walvis bay',
#  'cherskiy',
#  'asau',
#  'novyy oskol',
#  'altay',
#  'guarapari',
#  'vanimo',
#  'puerto palomas',
#  'ribeira grande',
#  'milicz',
#  'nuuk',
#  'maple creek',
#  'codajas',
#  'pacific grove',
#  'los llanos de aridane',
#  'eyl',
#  'mehamn',
#  'barrow',
#  'ashqelon',
#  'kieta',
#  'lavrentiya',
#  'hosangadi',
#  'moose factory',
#  'numi',
#  'huicungo',
#  'waipawa',
#  'hambantota',
#  'rawannawi',
#  'gazanjyk',
#  'alofi',
#  'ambagarh chauki',
#  'kathu',
#  'san-pedro',
#  'kloulklubed',
#  'colchester',
#  'samarai',
#  'lubango',
#  'yaan',
#  'ketchikan',
#  'high level',
#  'yamada',
#  'ambilobe',
#  'ampanihy',
#  'bubaque',
#  'nara',
#  'constitucion',
#  'bathsheba',
#  'shimoda',
#  'emerald',
#  'lac du bonnet',
#  'parrita',
#  'bellevue',
#  'kaitangata',
#  'mareeba',
#  'new haven',
#  'cah ab',
#  'grand river south east',
#  'bafq',
#  'nyrob',
#  'tasbuget',
#  'kawalu',
#  'promysla',
#  'kobryn',
#  'whitehorse',
#  'koslan',
#  'mahibadhoo',
#  'waingapu',
#  'ribeira brava',
#  'ksenyevka',
#  'bekasi',
#  'ardistan',
#  'half moon bay',
#  'nemuro',
#  'sola',
#  'mwinilunga',
#  'mutsamudu',
#  'casablanca',
#  'staraya toropa',
#  'ostersund',
#  'tripoli',
#  'tyukhtet',
#  'saint george',
#  'kruisfontein',
#  'kulti',
#  'iquique',
#  'san vicente',
#  'presidencia roque saenz pena',
#  'yagodnoye',
#  'markova',
#  'lichinga',
#  'amot',
#  'puerto madryn',
#  'dunedin',
#  'anshun',
#  'balkanabat',
#  'tuatapere',
#  'heihe',
#  'saleaula',
#  'beloha',
#  'eydhafushi',
#  'nanortalik',
#  'yar-sale',
#  'ostrovnoy',
#  'prince rupert',
#  'chara',
#  'karasjok',
#  'goundam',
#  'gazni',
#  'beasain',
#  'sawtell',
#  'daru',
#  'cukai',
#  'heinola',
#  'calais',
#  'bonfim',
#  'chumikan',
#  'meadow lake',
#  'isangel',
#  'port hardy',
#  'thornbury',
#  'river falls',
#  'komsomolskiy',
#  'pokhara',
#  'virginia beach',
#  'egersund',
#  'beyla',
#  'gobabis',
#  'tatawin',
#  'bauchi',
#  'haines junction',
#  'vardo',
#  'buariki',
#  'zhob',
#  'mogadishu',
#  'saurimo',
#  'pochutla',
#  'prainha',
#  'meulaboh',
#  'saryshagan',
#  'balykshi',
#  'coihaique',
#  'chupei',
#  'lompoc',
#  'straumen',
#  'juneau',
#  'west bay',
#  'jacareacanga',
#  'manta',
#  'patancheru',
#  'zarubino',
#  'nabire',
#  'ruatoria',
#  'lerwick',
#  'padang',
#  'nome',
#  'lockhart',
#  'ijaki',
#  'sterling',
#  'artyom',
#  'nazca',
#  'biltine',
#  'narok',
#  'tocantins',
#  'sabha',
#  'yumen',
#  'srednekolymsk',
#  'guapo',
#  'longlac',
#  'qaqortoq',
#  'nguiu',
#  'tay ninh',
#  'kars',
#  'mount isa',
#  'gorshechnoye',
#  'potam',
#  'alice springs',
#  'doctor juan leon mallorquin',
#  'vila franca do campo',
#  'sibu',
#  'canon city',
#  'birjand',
#  'north myrtle beach',
#  'sept-iles',
#  'mentok',
#  'nisia floresta',
#  'batemans bay',
#  'tocache',
#  'elat',
#  'arman',
#  'smithers',
#  'attawapiskat',
#  'sarwar',
#  'kazalinsk',
#  'mirabela',
#  'kupino',
#  'pierre',
#  'ridgecrest',
#  'velyka oleksandrivka',
#  'seoul',
#  'la peca',
#  'galle',
#  'mataram',
#  'tilichiki',
#  'koygorodok',
#  'kaoma',
#  'chapais',
#  'lakatoro',
#  'bar harbor',
#  'tommot',
#  'bedesa',
#  'grand centre',
#  'bandarbeyla',
#  'hammerfest',
#  'norman wells',
#  'griffith',
#  'yendi',
#  'luebo',
#  'olafsvik',
#  'moindou',
#  'lanzhou',
#  'barbosa ferraz',
#  'uyuni',
#  'hasaki',
#  'conde',
#  'tiruvottiyur',
#  'mragowo',
#  'sioux lookout',
#  'mangaratiba',
#  'newport',
#  'charagua',
#  'saint-augustin',
#  'katherine',
#  'broken hill',
#  'lolua',
#  'campbellsville',
#  'henties bay',
#  'malakal',
#  'marcona',
#  'longonjo',
#  'lasa',
#  'umzimvubu',
#  'tulum',
#  'aflu',
#  'la asuncion',
#  'ordzhonikidze',
#  'trebisacce',
#  'boueni',
#  'medina del campo',
#  'porbandar',
#  'atikokan',
#  'la plata',
#  'maykain',
#  'jinchang',
#  'vanavara',
#  'nizwa',
#  'berdigestyakh',
#  'buon me thuot',
#  'ejura',
#  'samana',
#  'zarinsk',
#  'flin flon',
#  'tefe',
#  'nhamunda',
#  'tungor',
#  'rosario',
#  'tadine',
#  'nsanje',
#  'fort nelson',
#  'tura',
#  'talcahuano',
#  'nazilli',
#  'margate',
#  'bahia blanca',
#  'binzhou',
#  'clyde river',
#  'berlevag',
#  'saint anthony',
#  'bhag',
#  'qui nhon',
#  'morro bay',
#  'termiz',
#  'medicine hat',
#  'viedma',
#  'oriximina',
#  'cucer',
#  'chagda',
#  'soure',
#  'lasalgaon',
#  'aklavik',
#  'port-gentil',
#  'kamaishi',
#  'hailar',
#  'warqla',
#  'green river',
#  'rungata',
#  'olinda',
#  'matamoros',
#  'port blair',
#  'soe',
#  'bitung',
#  'great yarmouth',
#  'baruun-urt',
#  'upington',
#  'vidim',
#  'kendari',
#  'dingle',
#  'khomeynishahr',
#  'flinders',
#  'tazovskiy',
#  'shestakovo',
#  'tucuman',
#  'gorno-altaysk',
#  'tumannyy',
#  'mvuma',
#  'rize',
#  'ambovombe',
#  'loviisa',
#  'kahului',
#  'hualmay',
#  'boulder city',
#  'esperance',
#  'hohhot',
#  'pleshanovo',
#  'sampit',
#  'kavaratti',
#  'peniche',
#  'hirara',
#  'homer',
#  'kangavar',
#  'bababe',
#  'thiruvananthapuram',
#  'mitsamiouli',
#  'redmond',
#  'skagastrond',
#  'nacozari',
#  'saint-georges',
#  'mancio lima',
#  'utiroa',
#  'comodoro rivadavia',
#  'marawi',
#  'sorong',
#  'kresttsy',
#  'mana',
#  'solovetskiy',
#  'polunochnoye',
#  'kattivakkam',
#  'kerteh',
#  'kinkala',
#  'oktyabrskoye',
#  'bilibino',
#  'sataua',
#  'beyneu',
#  'lamu',
#  'tiznit',
#  'castro alves',
#  'pinyug',
#  'nagar karnul',
#  'cheremukhovo',
#  'buin',
#  'hazorasp',
#  'idaho falls',
#  'seredka',
#  'sestri levante',
#  'shilka',
#  'karaul',
#  'kimbe',
#  'sistranda',
#  'sao felix do xingu',
#  'changping',
#  'cabo rojo',
#  'the valley',
#  'kenai',
#  'sahuaripa',
#  'yukuhashi',
#  'sarkand',
#  'timberlake',
#  'nador',
#  'paignton',
#  'washington',
#  'victor harbor',
#  'chemin grenier',
#  'karkaralinsk',
#  'sevenoaks',
#  'nelson bay',
#  'kangaatsiaq',
#  'bid',
#  'sao joao da barra',
#  'salym',
#  'agadez',
#  'oranjemund',
#  'nizhniy odes',
#  'lakes entrance',
#  'tessalit',
#  'belmonte',
#  'fukue',
#  'mgandu',
#  'sumbawa',
#  'akdagmadeni',
#  'bontang',
#  'ram das',
#  'vung tau',
#  'urdzhar',
#  'senmonorom',
#  'sobolevo',
#  'mendahara',
#  'inuvik',
#  'chicama',
#  'amnat charoen',
#  'ballangen',
#  'pitimbu',
#  'lufilufi',
#  'dicabisagan',
#  'kamenskoye',
#  'ormara',
#  'raga',
#  'betafo',
#  'belluru',
#  'thouars',
#  'jinchengjiang',
#  'fortuna foothills',
#  'diego de almagro',
#  'ilhabela',
#  'yima',
#  'tharad',
#  'fare',
#  'avera',
#  'dragalina',
#  'darhan',
#  'anjiang',
#  'namagiripettai',
#  'bahawalpur',
#  'nicoya',
#  'ulverstone',
#  'puga',
#  'zhigansk',
#  'namibe',
#  'khlung',
#  'paradwip',
#  'vao',
#  'gouyave',
#  'yining',
#  'tomatlan',
#  'tuy hoa',
#  'manzanillo',
#  'princeton',
#  'fairbanks',
#  'boyolangu',
#  'marsa matruh',
#  'beian',
#  'kurilsk',
#  'codrington',
#  'sherman',
#  'kidal',
#  'chapada dos guimaraes',
#  'poya',
#  'carauari',
#  'ondangwa',
#  'port hedland',
#  'wulanhaote',
#  'kostomuksha',
#  'forecariah',
#  'bourg-en-bresse',
#  'andenes',
#  'denpasar',
#  'severo-yeniseyskiy',
#  'katsuura']

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1 # 1 to 50 cities
set_count = 1 # no. of set of 50 cities

# Loop through all the cities in our list.
for i, city in enumerate(cities): # replaced: for i in range(len(cities)) --> this retruns index to URL. enumerate() returns city and index
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1 # resets the city count at the beginning of every new set
        time.sleep(60) # free tier allows 60 calls/minute. Tells program to stop for a minute after 50 calls preventing runtime errors
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+") # replace city name's spaces with + to concatenate

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1 #processes the next city

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve the data
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]####NOTE HERE. in JSON weather has 1 list. get from list 0
        
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({
            "City": city.title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            #"Date": city_date,
            "Current Description": city_weather_description
        })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        print(city_url)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | verkhoyansk
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | provideniya
# Processing Record 6 of Set 1 | carnarvon
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | korla
# Processing Record 10 of Set 1 | souillac
# Processing Record 11 of Set 1 | vila velha
# Processing Record 12 of Set 1 | coquimbo
# Processing Record 13 of Set 1 | westport
# Processing Record 14 of Set 1 | camana
# Processing Record 15 of Set 1 | longyearbyen
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | samusu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=samusu
# Processing Record 18 of Set 1 | tasiilaq
# Processing Record 19 of Set 1 | lubyany
# Processing Record 20 of Set 1 | wenatchee
# Processing Record 21 of Set 1 | yarada
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | cayenne
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | todos santos
# Processing Record 26 of Set 1 | tiarei
# Processing Record 27 of Set 1 | lisakovsk
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | rundu
# Processing Record 31 of Set 1 | saldanha
# Processing Record 32 of Set 1 | ouargaye
# Processing Record 33 of Set 1 | port augusta
# Processing Record 34 of Set 1 | grindavik
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | vaitupu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=vaitupu
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | livani
# Processing Record 40 of Set 1 | deogarh
# Processing Record 41 of Set 1 | brae
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | praia da vitoria
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | camopi
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=taolanaro
# Processing Record 50 of Set 1 | tezu
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | ixtapa
# Processing Record 4 of Set 2 | ayer itam
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=ayer+itam
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | rawson
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | herat
# Processing Record 10 of Set 2 | rocha
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | mporokoso
# Processing Record 13 of Set 2 | buraydah
# Processing Record 14 of Set 2 | san quintin
# Processing Record 15 of Set 2 | semey
# Processing Record 16 of Set 2 | paamiut
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | upernavik
# Processing Record 20 of Set 2 | merauke
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | sorland
# Processing Record 23 of Set 2 | krasnoselkup
# Processing Record 24 of Set 2 | klaksvik
# Processing Record 25 of Set 2 | tautira
# Processing Record 26 of Set 2 | ilulissat
# Processing Record 27 of Set 2 | touros
# Processing Record 28 of Set 2 | hit
# Processing Record 29 of Set 2 | igarka
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | mauriti
# Processing Record 32 of Set 2 | faanui
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | akyab
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | xining
# Processing Record 37 of Set 2 | caravelas
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | nyurba
# Processing Record 40 of Set 2 | tsihombe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=tsihombe
# Processing Record 41 of Set 2 | bargal
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=bargal
# Processing Record 42 of Set 2 | te anau
# Processing Record 43 of Set 2 | barbar
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=barbar
# Processing Record 44 of Set 2 | pevek
# Processing Record 45 of Set 2 | norilsk
# Processing Record 46 of Set 2 | batsfjord
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | karratha
# Processing Record 49 of Set 2 | cape town
# Processing Record 50 of Set 2 | atar
# Processing Record 1 of Set 3 | bacabal
# Processing Record 2 of Set 3 | vorkuta
# Processing Record 3 of Set 3 | lata
# Processing Record 4 of Set 3 | novoagansk
# Processing Record 5 of Set 3 | tandil
# Processing Record 6 of Set 3 | deputatskiy
# Processing Record 7 of Set 3 | the pas
# Processing Record 8 of Set 3 | cidreira
# Processing Record 9 of Set 3 | yalta
# Processing Record 10 of Set 3 | kosa
# Processing Record 11 of Set 3 | louisbourg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=louisbourg
# Processing Record 12 of Set 3 | itarema
# Processing Record 13 of Set 3 | erzin
# Processing Record 14 of Set 3 | talnakh
# Processing Record 15 of Set 3 | kapaa
# Processing Record 16 of Set 3 | guerrero negro
# Processing Record 17 of Set 3 | nikolskoye
# Processing Record 18 of Set 3 | narsaq
# Processing Record 19 of Set 3 | rumonge
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | chuy
# Processing Record 22 of Set 3 | mirnyy
# Processing Record 23 of Set 3 | ahipara
# Processing Record 24 of Set 3 | tupelo
# Processing Record 25 of Set 3 | kununurra
# Processing Record 26 of Set 3 | belyy yar
# Processing Record 27 of Set 3 | freeport
# Processing Record 28 of Set 3 | mangrol
# Processing Record 29 of Set 3 | cabedelo
# Processing Record 30 of Set 3 | kodiak
# Processing Record 31 of Set 3 | amapa
# Processing Record 32 of Set 3 | cabo san lucas
# Processing Record 33 of Set 3 | naryan-mar
# Processing Record 34 of Set 3 | airai
# Processing Record 35 of Set 3 | victoria
# Processing Record 36 of Set 3 | hofn
# Processing Record 37 of Set 3 | nalut
# Processing Record 38 of Set 3 | bengkulu
# Processing Record 39 of Set 3 | svetlyy
# Processing Record 40 of Set 3 | ancud
# Processing Record 41 of Set 3 | udachnyy
# Processing Record 42 of Set 3 | khorixas
# Processing Record 43 of Set 3 | tiksi
# Processing Record 44 of Set 3 | port elizabeth
# Processing Record 45 of Set 3 | zyryanovskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=zyryanovskiy
# Processing Record 46 of Set 3 | harper
# Processing Record 47 of Set 3 | campbell river
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | luderitz
# Processing Record 50 of Set 3 | basco
# Processing Record 1 of Set 4 | ploemeur
# Processing Record 2 of Set 4 | bismarck
# Processing Record 3 of Set 4 | pangnirtung
# Processing Record 4 of Set 4 | havre-saint-pierre
# Processing Record 5 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=illoqqortoormiut
# Processing Record 6 of Set 4 | mao
# Processing Record 7 of Set 4 | bulgan
# Processing Record 8 of Set 4 | agirish
# Processing Record 9 of Set 4 | hobyo
# Processing Record 10 of Set 4 | keti bandar
# Processing Record 11 of Set 4 | nantucket
# Processing Record 12 of Set 4 | pochinki
# Processing Record 13 of Set 4 | hojai
# Processing Record 14 of Set 4 | price
# Processing Record 15 of Set 4 | hoima
# Processing Record 16 of Set 4 | saint-philippe
# Processing Record 17 of Set 4 | atuona
# Processing Record 18 of Set 4 | mastic beach
# Processing Record 19 of Set 4 | mys shmidta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=mys+shmidta
# Processing Record 20 of Set 4 | grand gaube
# Processing Record 21 of Set 4 | zyryanovsk
# Processing Record 22 of Set 4 | matara
# Processing Record 23 of Set 4 | bonoua
# Processing Record 24 of Set 4 | martapura
# Processing Record 25 of Set 4 | berezovyy
# Processing Record 26 of Set 4 | cockburn town
# Processing Record 27 of Set 4 | kiama
# Processing Record 28 of Set 4 | sao filipe
# Processing Record 29 of Set 4 | vilkaviskis
# Processing Record 30 of Set 4 | pozo colorado
# Processing Record 31 of Set 4 | salalah
# Processing Record 32 of Set 4 | iqaluit
# Processing Record 33 of Set 4 | evensk
# Processing Record 34 of Set 4 | lebu
# Processing Record 35 of Set 4 | vestmannaeyjar
# Processing Record 36 of Set 4 | rayong
# Processing Record 37 of Set 4 | tambovka
# Processing Record 38 of Set 4 | san cristobal
# Processing Record 39 of Set 4 | mount gambier
# Processing Record 40 of Set 4 | geraldton
# Processing Record 41 of Set 4 | laguna
# Processing Record 42 of Set 4 | rio gallegos
# Processing Record 43 of Set 4 | mocuba
# Processing Record 44 of Set 4 | fortuna
# Processing Record 45 of Set 4 | new ulm
# Processing Record 46 of Set 4 | kemijarvi
# Processing Record 47 of Set 4 | bud
# Processing Record 48 of Set 4 | luganville
# Processing Record 49 of Set 4 | torbay
# Processing Record 50 of Set 4 | carutapera
# Processing Record 1 of Set 5 | kutum
# Processing Record 2 of Set 5 | abu dhabi
# Processing Record 3 of Set 5 | broome
# Processing Record 4 of Set 5 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=belushya+guba
# Processing Record 5 of Set 5 | hovd
# Processing Record 6 of Set 5 | kenora
# Processing Record 7 of Set 5 | gizo
# Processing Record 8 of Set 5 | awbari
# Processing Record 9 of Set 5 | ponta do sol
# Processing Record 10 of Set 5 | port lincoln
# Processing Record 11 of Set 5 | yulara
# Processing Record 12 of Set 5 | moron
# Processing Record 13 of Set 5 | kirakira
# Processing Record 14 of Set 5 | kisangani
# Processing Record 15 of Set 5 | yeppoon
# Processing Record 16 of Set 5 | khandyga
# Processing Record 17 of Set 5 | jambi
# Processing Record 18 of Set 5 | skjervoy
# Processing Record 19 of Set 5 | arlit
# Processing Record 20 of Set 5 | hoquiam
# Processing Record 21 of Set 5 | wanxian
# Processing Record 22 of Set 5 | perpignan
# Processing Record 23 of Set 5 | college
# Processing Record 24 of Set 5 | luanda
# Processing Record 25 of Set 5 | lujan
# Processing Record 26 of Set 5 | jiddah
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=jiddah
# Processing Record 27 of Set 5 | poltsamaa
# Processing Record 28 of Set 5 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=nizhneyansk
# Processing Record 29 of Set 5 | chimore
# Processing Record 30 of Set 5 | ayan
# Processing Record 31 of Set 5 | itaituba
# Processing Record 32 of Set 5 | lagoa
# Processing Record 33 of Set 5 | sentyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=sentyabrskiy
# Processing Record 34 of Set 5 | kroya
# Processing Record 35 of Set 5 | san patricio
# Processing Record 36 of Set 5 | beckley
# Processing Record 37 of Set 5 | tabiauea
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=tabiauea
# Processing Record 38 of Set 5 | egvekinot
# Processing Record 39 of Set 5 | banyo
# Processing Record 40 of Set 5 | aswan
# Processing Record 41 of Set 5 | nouadhibou
# Processing Record 42 of Set 5 | zhuhai
# Processing Record 43 of Set 5 | lorengau
# Processing Record 44 of Set 5 | preobrazheniye
# Processing Record 45 of Set 5 | rio verde de mato grosso
# Processing Record 46 of Set 5 | catabola
# Processing Record 47 of Set 5 | trebur
# Processing Record 48 of Set 5 | sitka
# Processing Record 49 of Set 5 | duobao
# Processing Record 50 of Set 5 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=barentsburg
# Processing Record 1 of Set 6 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=amderma
# Processing Record 2 of Set 6 | quchan
# Processing Record 3 of Set 6 | palabuhanratu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=palabuhanratu
# Processing Record 4 of Set 6 | taltal
# Processing Record 5 of Set 6 | khatanga
# Processing Record 6 of Set 6 | radhanpur
# Processing Record 7 of Set 6 | tevriz
# Processing Record 8 of Set 6 | vitimskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=vitimskiy
# Processing Record 9 of Set 6 | tual
# Processing Record 10 of Set 6 | lagos
# Processing Record 11 of Set 6 | portland
# Processing Record 12 of Set 6 | thunder bay
# Processing Record 13 of Set 6 | carlet
# Processing Record 14 of Set 6 | naze
# Processing Record 15 of Set 6 | gongzhuling
# Processing Record 16 of Set 6 | calabozo
# Processing Record 17 of Set 6 | alyangula
# Processing Record 18 of Set 6 | kavieng
# Processing Record 19 of Set 6 | bethel
# Processing Record 20 of Set 6 | walvis bay
# Processing Record 21 of Set 6 | cherskiy
# Processing Record 22 of Set 6 | asau
# Processing Record 23 of Set 6 | novyy oskol
# Processing Record 24 of Set 6 | altay
# Processing Record 25 of Set 6 | guarapari
# Processing Record 26 of Set 6 | vanimo
# Processing Record 27 of Set 6 | puerto palomas
# Processing Record 28 of Set 6 | ribeira grande
# Processing Record 29 of Set 6 | milicz
# Processing Record 30 of Set 6 | nuuk
# Processing Record 31 of Set 6 | maple creek
# Processing Record 32 of Set 6 | codajas
# Processing Record 33 of Set 6 | pacific grove
# Processing Record 34 of Set 6 | los llanos de aridane
# Processing Record 35 of Set 6 | eyl
# Processing Record 36 of Set 6 | mehamn
# Processing Record 37 of Set 6 | barrow
# Processing Record 38 of Set 6 | ashqelon
# Processing Record 39 of Set 6 | kieta
# Processing Record 40 of Set 6 | lavrentiya
# Processing Record 41 of Set 6 | hosangadi
# Processing Record 42 of Set 6 | moose factory
# Processing Record 43 of Set 6 | numi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=numi
# Processing Record 44 of Set 6 | huicungo
# Processing Record 45 of Set 6 | waipawa
# Processing Record 46 of Set 6 | hambantota
# Processing Record 47 of Set 6 | rawannawi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=rawannawi
# Processing Record 48 of Set 6 | gazanjyk
# Processing Record 49 of Set 6 | alofi
# Processing Record 50 of Set 6 | ambagarh chauki
# Processing Record 1 of Set 7 | kathu
# Processing Record 2 of Set 7 | san-pedro
# Processing Record 3 of Set 7 | kloulklubed
# Processing Record 4 of Set 7 | colchester
# Processing Record 5 of Set 7 | samarai
# Processing Record 6 of Set 7 | lubango
# Processing Record 7 of Set 7 | yaan
# Processing Record 8 of Set 7 | ketchikan
# Processing Record 9 of Set 7 | high level
# Processing Record 10 of Set 7 | yamada
# Processing Record 11 of Set 7 | ambilobe
# Processing Record 12 of Set 7 | ampanihy
# Processing Record 13 of Set 7 | bubaque
# Processing Record 14 of Set 7 | nara
# Processing Record 15 of Set 7 | constitucion
# Processing Record 16 of Set 7 | bathsheba
# Processing Record 17 of Set 7 | shimoda
# Processing Record 18 of Set 7 | emerald
# Processing Record 19 of Set 7 | lac du bonnet
# Processing Record 20 of Set 7 | parrita
# Processing Record 21 of Set 7 | bellevue
# Processing Record 22 of Set 7 | kaitangata
# Processing Record 23 of Set 7 | mareeba
# Processing Record 24 of Set 7 | new haven
# Processing Record 25 of Set 7 | cah ab
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=cah+ab
# Processing Record 26 of Set 7 | grand river south east
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=grand+river+south+east
# Processing Record 27 of Set 7 | bafq
# Processing Record 28 of Set 7 | nyrob
# Processing Record 29 of Set 7 | tasbuget
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=tasbuget
# Processing Record 30 of Set 7 | kawalu
# Processing Record 31 of Set 7 | promysla
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=promysla
# Processing Record 32 of Set 7 | kobryn
# Processing Record 33 of Set 7 | whitehorse
# Processing Record 34 of Set 7 | koslan
# Processing Record 35 of Set 7 | mahibadhoo
# Processing Record 36 of Set 7 | waingapu
# Processing Record 37 of Set 7 | ribeira brava
# Processing Record 38 of Set 7 | ksenyevka
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=ksenyevka
# Processing Record 39 of Set 7 | bekasi
# Processing Record 40 of Set 7 | ardistan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=ardistan
# Processing Record 41 of Set 7 | half moon bay
# Processing Record 42 of Set 7 | nemuro
# Processing Record 43 of Set 7 | sola
# Processing Record 44 of Set 7 | mwinilunga
# Processing Record 45 of Set 7 | mutsamudu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=mutsamudu
# Processing Record 46 of Set 7 | casablanca
# Processing Record 47 of Set 7 | staraya toropa
# Processing Record 48 of Set 7 | ostersund
# Processing Record 49 of Set 7 | tripoli
# Processing Record 50 of Set 7 | tyukhtet
# Processing Record 1 of Set 8 | saint george
# Processing Record 2 of Set 8 | kruisfontein
# Processing Record 3 of Set 8 | kulti
# Processing Record 4 of Set 8 | iquique
# Processing Record 5 of Set 8 | san vicente
# Processing Record 6 of Set 8 | presidencia roque saenz pena
# Processing Record 7 of Set 8 | yagodnoye
# Processing Record 8 of Set 8 | markova
# Processing Record 9 of Set 8 | lichinga
# Processing Record 10 of Set 8 | amot
# Processing Record 11 of Set 8 | puerto madryn
# Processing Record 12 of Set 8 | dunedin
# Processing Record 13 of Set 8 | anshun
# Processing Record 14 of Set 8 | balkanabat
# Processing Record 15 of Set 8 | tuatapere
# Processing Record 16 of Set 8 | heihe
# Processing Record 17 of Set 8 | saleaula
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=saleaula
# Processing Record 18 of Set 8 | beloha
# Processing Record 19 of Set 8 | eydhafushi
# Processing Record 20 of Set 8 | nanortalik
# Processing Record 21 of Set 8 | yar-sale
# Processing Record 22 of Set 8 | ostrovnoy
# Processing Record 23 of Set 8 | prince rupert
# Processing Record 24 of Set 8 | chara
# Processing Record 25 of Set 8 | karasjok
# Processing Record 26 of Set 8 | goundam
# Processing Record 27 of Set 8 | gazni
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=gazni
# Processing Record 28 of Set 8 | beasain
# Processing Record 29 of Set 8 | sawtell
# Processing Record 30 of Set 8 | daru
# Processing Record 31 of Set 8 | cukai
# Processing Record 32 of Set 8 | heinola
# Processing Record 33 of Set 8 | calais
# Processing Record 34 of Set 8 | bonfim
# Processing Record 35 of Set 8 | chumikan
# Processing Record 36 of Set 8 | meadow lake
# Processing Record 37 of Set 8 | isangel
# Processing Record 38 of Set 8 | port hardy
# Processing Record 39 of Set 8 | thornbury
# Processing Record 40 of Set 8 | river falls
# Processing Record 41 of Set 8 | komsomolskiy
# Processing Record 42 of Set 8 | pokhara
# Processing Record 43 of Set 8 | virginia beach
# Processing Record 44 of Set 8 | egersund
# Processing Record 45 of Set 8 | beyla
# Processing Record 46 of Set 8 | gobabis
# Processing Record 47 of Set 8 | tatawin
# Processing Record 48 of Set 8 | bauchi
# Processing Record 49 of Set 8 | haines junction
# Processing Record 50 of Set 8 | vardo
# Processing Record 1 of Set 9 | buariki
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=buariki
# Processing Record 2 of Set 9 | zhob
# Processing Record 3 of Set 9 | mogadishu
# Processing Record 4 of Set 9 | saurimo
# Processing Record 5 of Set 9 | pochutla
# Processing Record 6 of Set 9 | prainha
# Processing Record 7 of Set 9 | meulaboh
# Processing Record 8 of Set 9 | saryshagan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=saryshagan
# Processing Record 9 of Set 9 | balykshi
# Processing Record 10 of Set 9 | coihaique
# Processing Record 11 of Set 9 | chupei
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=chupei
# Processing Record 12 of Set 9 | lompoc
# Processing Record 13 of Set 9 | straumen
# Processing Record 14 of Set 9 | juneau
# Processing Record 15 of Set 9 | west bay
# Processing Record 16 of Set 9 | jacareacanga
# Processing Record 17 of Set 9 | manta
# Processing Record 18 of Set 9 | patancheru
# Processing Record 19 of Set 9 | zarubino
# Processing Record 20 of Set 9 | nabire
# Processing Record 21 of Set 9 | ruatoria
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=ruatoria
# Processing Record 22 of Set 9 | lerwick
# Processing Record 23 of Set 9 | padang
# Processing Record 24 of Set 9 | nome
# Processing Record 25 of Set 9 | lockhart
# Processing Record 26 of Set 9 | ijaki
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=ijaki
# Processing Record 27 of Set 9 | sterling
# Processing Record 28 of Set 9 | artyom
# Processing Record 29 of Set 9 | nazca
# Processing Record 30 of Set 9 | biltine
# Processing Record 31 of Set 9 | narok
# Processing Record 32 of Set 9 | tocantins
# Processing Record 33 of Set 9 | sabha
# Processing Record 34 of Set 9 | yumen
# Processing Record 35 of Set 9 | srednekolymsk
# Processing Record 36 of Set 9 | guapo
# Processing Record 37 of Set 9 | longlac
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=longlac
# Processing Record 38 of Set 9 | qaqortoq
# Processing Record 39 of Set 9 | nguiu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=nguiu
# Processing Record 40 of Set 9 | tay ninh
# Processing Record 41 of Set 9 | kars
# Processing Record 42 of Set 9 | mount isa
# Processing Record 43 of Set 9 | gorshechnoye
# Processing Record 44 of Set 9 | potam
# Processing Record 45 of Set 9 | alice springs
# Processing Record 46 of Set 9 | doctor juan leon mallorquin
# Processing Record 47 of Set 9 | vila franca do campo
# Processing Record 48 of Set 9 | sibu
# Processing Record 49 of Set 9 | canon city
# Processing Record 50 of Set 9 | birjand
# Processing Record 1 of Set 10 | north myrtle beach
# Processing Record 2 of Set 10 | sept-iles
# Processing Record 3 of Set 10 | mentok
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=mentok
# Processing Record 4 of Set 10 | nisia floresta
# Processing Record 5 of Set 10 | batemans bay
# Processing Record 6 of Set 10 | tocache
# Processing Record 7 of Set 10 | elat
# Processing Record 8 of Set 10 | arman
# Processing Record 9 of Set 10 | smithers
# Processing Record 10 of Set 10 | attawapiskat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=attawapiskat
# Processing Record 11 of Set 10 | sarwar
# Processing Record 12 of Set 10 | kazalinsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=kazalinsk
# Processing Record 13 of Set 10 | mirabela
# Processing Record 14 of Set 10 | kupino
# Processing Record 15 of Set 10 | pierre
# Processing Record 16 of Set 10 | ridgecrest
# Processing Record 17 of Set 10 | velyka oleksandrivka
# Processing Record 18 of Set 10 | seoul
# Processing Record 19 of Set 10 | la peca
# Processing Record 20 of Set 10 | galle
# Processing Record 21 of Set 10 | mataram
# Processing Record 22 of Set 10 | tilichiki
# Processing Record 23 of Set 10 | koygorodok
# Processing Record 24 of Set 10 | kaoma
# Processing Record 25 of Set 10 | chapais
# Processing Record 26 of Set 10 | lakatoro
# Processing Record 27 of Set 10 | bar harbor
# Processing Record 28 of Set 10 | tommot
# Processing Record 29 of Set 10 | bedesa
# Processing Record 30 of Set 10 | grand centre
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=grand+centre
# Processing Record 31 of Set 10 | bandarbeyla
# Processing Record 32 of Set 10 | hammerfest
# Processing Record 33 of Set 10 | norman wells
# Processing Record 34 of Set 10 | griffith
# Processing Record 35 of Set 10 | yendi
# Processing Record 36 of Set 10 | luebo
# Processing Record 37 of Set 10 | olafsvik
# Processing Record 38 of Set 10 | moindou
# Processing Record 39 of Set 10 | lanzhou
# Processing Record 40 of Set 10 | barbosa ferraz
# Processing Record 41 of Set 10 | uyuni
# Processing Record 42 of Set 10 | hasaki
# Processing Record 43 of Set 10 | conde
# Processing Record 44 of Set 10 | tiruvottiyur
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=tiruvottiyur
# Processing Record 45 of Set 10 | mragowo
# Processing Record 46 of Set 10 | sioux lookout
# Processing Record 47 of Set 10 | mangaratiba
# Processing Record 48 of Set 10 | newport
# Processing Record 49 of Set 10 | charagua
# Processing Record 50 of Set 10 | saint-augustin
# Processing Record 1 of Set 11 | katherine
# Processing Record 2 of Set 11 | broken hill
# Processing Record 3 of Set 11 | lolua
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=lolua
# Processing Record 4 of Set 11 | campbellsville
# Processing Record 5 of Set 11 | henties bay
# Processing Record 6 of Set 11 | malakal
# Processing Record 7 of Set 11 | marcona
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=marcona
# Processing Record 8 of Set 11 | longonjo
# Processing Record 9 of Set 11 | lasa
# Processing Record 10 of Set 11 | umzimvubu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=umzimvubu
# Processing Record 11 of Set 11 | tulum
# Processing Record 12 of Set 11 | aflu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=aflu
# Processing Record 13 of Set 11 | la asuncion
# Processing Record 14 of Set 11 | ordzhonikidze
# Processing Record 15 of Set 11 | trebisacce
# Processing Record 16 of Set 11 | boueni
# Processing Record 17 of Set 11 | medina del campo
# Processing Record 18 of Set 11 | porbandar
# Processing Record 19 of Set 11 | atikokan
# Processing Record 20 of Set 11 | la plata
# Processing Record 21 of Set 11 | maykain
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=maykain
# Processing Record 22 of Set 11 | jinchang
# Processing Record 23 of Set 11 | vanavara
# Processing Record 24 of Set 11 | nizwa
# Processing Record 25 of Set 11 | berdigestyakh
# Processing Record 26 of Set 11 | buon me thuot
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=buon+me+thuot
# Processing Record 27 of Set 11 | ejura
# Processing Record 28 of Set 11 | samana
# Processing Record 29 of Set 11 | zarinsk
# Processing Record 30 of Set 11 | flin flon
# Processing Record 31 of Set 11 | tefe
# Processing Record 32 of Set 11 | nhamunda
# Processing Record 33 of Set 11 | tungor
# Processing Record 34 of Set 11 | rosario
# Processing Record 35 of Set 11 | tadine
# Processing Record 36 of Set 11 | nsanje
# Processing Record 37 of Set 11 | fort nelson
# Processing Record 38 of Set 11 | tura
# Processing Record 39 of Set 11 | talcahuano
# Processing Record 40 of Set 11 | nazilli
# Processing Record 41 of Set 11 | margate
# Processing Record 42 of Set 11 | bahia blanca
# Processing Record 43 of Set 11 | binzhou
# Processing Record 44 of Set 11 | clyde river
# Processing Record 45 of Set 11 | berlevag
# Processing Record 46 of Set 11 | saint anthony
# Processing Record 47 of Set 11 | bhag
# Processing Record 48 of Set 11 | qui nhon
# Processing Record 49 of Set 11 | morro bay
# Processing Record 50 of Set 11 | termiz
# Processing Record 1 of Set 12 | medicine hat
# Processing Record 2 of Set 12 | viedma
# Processing Record 3 of Set 12 | oriximina
# Processing Record 4 of Set 12 | cucer
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=cucer
# Processing Record 5 of Set 12 | chagda
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=chagda
# Processing Record 6 of Set 12 | soure
# Processing Record 7 of Set 12 | lasalgaon
# Processing Record 8 of Set 12 | aklavik
# Processing Record 9 of Set 12 | port-gentil
# Processing Record 10 of Set 12 | kamaishi
# Processing Record 11 of Set 12 | hailar
# Processing Record 12 of Set 12 | warqla
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=warqla
# Processing Record 13 of Set 12 | green river
# Processing Record 14 of Set 12 | rungata
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=rungata
# Processing Record 15 of Set 12 | olinda
# Processing Record 16 of Set 12 | matamoros
# Processing Record 17 of Set 12 | port blair
# Processing Record 18 of Set 12 | soe
# Processing Record 19 of Set 12 | bitung
# Processing Record 20 of Set 12 | great yarmouth
# Processing Record 21 of Set 12 | baruun-urt
# Processing Record 22 of Set 12 | upington
# Processing Record 23 of Set 12 | vidim
# Processing Record 24 of Set 12 | kendari
# Processing Record 25 of Set 12 | dingle
# Processing Record 26 of Set 12 | khomeynishahr
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=khomeynishahr
# Processing Record 27 of Set 12 | flinders
# Processing Record 28 of Set 12 | tazovskiy
# Processing Record 29 of Set 12 | shestakovo
# Processing Record 30 of Set 12 | tucuman
# Processing Record 31 of Set 12 | gorno-altaysk
# Processing Record 32 of Set 12 | tumannyy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=tumannyy
# Processing Record 33 of Set 12 | mvuma
# Processing Record 34 of Set 12 | rize
# Processing Record 35 of Set 12 | ambovombe
# Processing Record 36 of Set 12 | loviisa
# Processing Record 37 of Set 12 | kahului
# Processing Record 38 of Set 12 | hualmay
# Processing Record 39 of Set 12 | boulder city
# Processing Record 40 of Set 12 | esperance
# Processing Record 41 of Set 12 | hohhot
# Processing Record 42 of Set 12 | pleshanovo
# Processing Record 43 of Set 12 | sampit
# Processing Record 44 of Set 12 | kavaratti
# Processing Record 45 of Set 12 | peniche
# Processing Record 46 of Set 12 | hirara
# Processing Record 47 of Set 12 | homer
# Processing Record 48 of Set 12 | kangavar
# Processing Record 49 of Set 12 | bababe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=bababe
# Processing Record 50 of Set 12 | thiruvananthapuram
# Processing Record 1 of Set 13 | mitsamiouli
# Processing Record 2 of Set 13 | redmond
# Processing Record 3 of Set 13 | skagastrond
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=skagastrond
# Processing Record 4 of Set 13 | nacozari
# Processing Record 5 of Set 13 | saint-georges
# Processing Record 6 of Set 13 | mancio lima
# Processing Record 7 of Set 13 | utiroa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=utiroa
# Processing Record 8 of Set 13 | comodoro rivadavia
# Processing Record 9 of Set 13 | marawi
# Processing Record 10 of Set 13 | sorong
# Processing Record 11 of Set 13 | kresttsy
# Processing Record 12 of Set 13 | mana
# Processing Record 13 of Set 13 | solovetskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=solovetskiy
# Processing Record 14 of Set 13 | polunochnoye
# Processing Record 15 of Set 13 | kattivakkam
# Processing Record 16 of Set 13 | kerteh
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=kerteh
# Processing Record 17 of Set 13 | kinkala
# Processing Record 18 of Set 13 | oktyabrskoye
# Processing Record 19 of Set 13 | bilibino
# Processing Record 20 of Set 13 | sataua
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=sataua
# Processing Record 21 of Set 13 | beyneu
# Processing Record 22 of Set 13 | lamu
# Processing Record 23 of Set 13 | tiznit
# Processing Record 24 of Set 13 | castro alves
# Processing Record 25 of Set 13 | pinyug
# Processing Record 26 of Set 13 | nagar karnul
# Processing Record 27 of Set 13 | cheremukhovo
# Processing Record 28 of Set 13 | buin
# Processing Record 29 of Set 13 | hazorasp
# Processing Record 30 of Set 13 | idaho falls
# Processing Record 31 of Set 13 | seredka
# Processing Record 32 of Set 13 | sestri levante
# Processing Record 33 of Set 13 | shilka
# Processing Record 34 of Set 13 | karaul
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=karaul
# Processing Record 35 of Set 13 | kimbe
# Processing Record 36 of Set 13 | sistranda
# Processing Record 37 of Set 13 | sao felix do xingu
# Processing Record 38 of Set 13 | changping
# Processing Record 39 of Set 13 | cabo rojo
# Processing Record 40 of Set 13 | the valley
# Processing Record 41 of Set 13 | kenai
# Processing Record 42 of Set 13 | sahuaripa
# Processing Record 43 of Set 13 | yukuhashi
# Processing Record 44 of Set 13 | sarkand
# Processing Record 45 of Set 13 | timberlake
# Processing Record 46 of Set 13 | nador
# Processing Record 47 of Set 13 | paignton
# Processing Record 48 of Set 13 | washington
# Processing Record 49 of Set 13 | victor harbor
# Processing Record 50 of Set 13 | chemin grenier
# Processing Record 1 of Set 14 | karkaralinsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=karkaralinsk
# Processing Record 2 of Set 14 | sevenoaks
# Processing Record 3 of Set 14 | nelson bay
# Processing Record 4 of Set 14 | kangaatsiaq
# Processing Record 5 of Set 14 | bid
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=bid
# Processing Record 6 of Set 14 | sao joao da barra
# Processing Record 7 of Set 14 | salym
# Processing Record 8 of Set 14 | agadez
# Processing Record 9 of Set 14 | oranjemund
# Processing Record 10 of Set 14 | nizhniy odes
# Processing Record 11 of Set 14 | lakes entrance
# Processing Record 12 of Set 14 | tessalit
# Processing Record 13 of Set 14 | belmonte
# Processing Record 14 of Set 14 | fukue
# Processing Record 15 of Set 14 | mgandu
# Processing Record 16 of Set 14 | sumbawa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=sumbawa
# Processing Record 17 of Set 14 | akdagmadeni
# Processing Record 18 of Set 14 | bontang
# Processing Record 19 of Set 14 | ram das
# Processing Record 20 of Set 14 | vung tau
# Processing Record 21 of Set 14 | urdzhar
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=urdzhar
# Processing Record 22 of Set 14 | senmonorom
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=senmonorom
# Processing Record 23 of Set 14 | sobolevo
# Processing Record 24 of Set 14 | mendahara
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=mendahara
# Processing Record 25 of Set 14 | inuvik
# Processing Record 26 of Set 14 | chicama
# Processing Record 27 of Set 14 | amnat charoen
# Processing Record 28 of Set 14 | ballangen
# Processing Record 29 of Set 14 | pitimbu
# Processing Record 30 of Set 14 | lufilufi
# Processing Record 31 of Set 14 | dicabisagan
# Processing Record 32 of Set 14 | kamenskoye
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=kamenskoye
# Processing Record 33 of Set 14 | ormara
# Processing Record 34 of Set 14 | raga
# Processing Record 35 of Set 14 | betafo
# Processing Record 36 of Set 14 | belluru
# Processing Record 37 of Set 14 | thouars
# Processing Record 38 of Set 14 | jinchengjiang
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=jinchengjiang
# Processing Record 39 of Set 14 | fortuna foothills
# Processing Record 40 of Set 14 | diego de almagro
# Processing Record 41 of Set 14 | ilhabela
# Processing Record 42 of Set 14 | yima
# Processing Record 43 of Set 14 | tharad
# Processing Record 44 of Set 14 | fare
# Processing Record 45 of Set 14 | avera
# Processing Record 46 of Set 14 | dragalina
# Processing Record 47 of Set 14 | darhan
# Processing Record 48 of Set 14 | anjiang
# Processing Record 49 of Set 14 | namagiripettai
# Processing Record 50 of Set 14 | bahawalpur
# Processing Record 1 of Set 15 | nicoya
# Processing Record 2 of Set 15 | ulverstone
# Processing Record 3 of Set 15 | puga
# Processing Record 4 of Set 15 | zhigansk
# Processing Record 5 of Set 15 | namibe
# Processing Record 6 of Set 15 | khlung
# Processing Record 7 of Set 15 | paradwip
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=paradwip
# Processing Record 8 of Set 15 | vao
# Processing Record 9 of Set 15 | gouyave
# Processing Record 10 of Set 15 | yining
# Processing Record 11 of Set 15 | tomatlan
# Processing Record 12 of Set 15 | tuy hoa
# Processing Record 13 of Set 15 | manzanillo
# Processing Record 14 of Set 15 | princeton
# Processing Record 15 of Set 15 | fairbanks
# Processing Record 16 of Set 15 | boyolangu
# Processing Record 17 of Set 15 | marsa matruh
# Processing Record 18 of Set 15 | beian
# Processing Record 19 of Set 15 | kurilsk
# Processing Record 20 of Set 15 | codrington
# Processing Record 21 of Set 15 | sherman
# Processing Record 22 of Set 15 | kidal
# Processing Record 23 of Set 15 | chapada dos guimaraes
# Processing Record 24 of Set 15 | poya
# Processing Record 25 of Set 15 | carauari
# Processing Record 26 of Set 15 | ondangwa
# Processing Record 27 of Set 15 | port hedland
# Processing Record 28 of Set 15 | wulanhaote
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2c5a3292ca89f5d46553a133e524fa3f&q=wulanhaote
# Processing Record 29 of Set 15 | kostomuksha
# Processing Record 30 of Set 15 | forecariah
# Processing Record 31 of Set 15 | bourg-en-bresse
# Processing Record 32 of Set 15 | andenes
# Processing Record 33 of Set 15 | denpasar
# Processing Record 34 of Set 15 | severo-yeniseyskiy
# Processing Record 35 of Set 15 | katsuura
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Castro      BR -24.7911  -50.0119     58.51        71           3
# 1  Severo-Kurilsk      RU  50.6789  156.1250     31.19        77          86
# 2     Verkhoyansk      RU  67.5447  133.3850     -1.80        98          57
# 3         Rikitea      PF -23.1203 -134.9692     78.42        69           1
# 4     Provideniya      RU  64.3833 -173.3000     32.11        93         100
# 5       Carnarvon      AU -24.8667  113.6333     66.27        88         100
# 6      Chokurdakh      RU  70.6333  147.9167     -1.16        99          91
# 7         Mataura      NZ -46.1927  168.8643     40.48        81           0
# 8           Korla      CN  41.7597   86.1469     55.90        15           2
# 9        Souillac      MU -20.5167   57.5167     77.38        94          75
#
#    Wind Speed Current Description
# 0        1.81           clear sky
# 1        7.63     overcast clouds
# 2        1.66       broken clouds
# 3       12.66           clear sky
# 4       24.61                snow
# 5        6.91     overcast clouds
# 6        4.36     overcast clouds
# 7        1.74           clear sky
# 8        6.71           clear sky
# 9        1.14          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = "City_ID")
